# %% [markdown]
# # question 1
# A point estimate is a single value estimate of a unknown population parameter. For instance, a sample mean is a point estimate of a population mean. An interval estimate gives you a range of values where the parameter is expected to lie. A confidence interval is the most common type of interval estimate.

# %% [markdown]
# # question 2

# %%
def estimate_population_mean(sample_mean, sample_std_dev, sample_size):
    # Calculate the standard error of the mean
    std_error_mean = sample_std_dev / (sample_size ** 0.5)
    
    # Calculate the lower and upper bounds of the 95% confidence interval
    lower_bound = sample_mean - 1.96 * std_error_mean
    upper_bound = sample_mean + 1.96 * std_error_mean
    
    # Return the estimated population mean
    return round(sample_mean, 2), round(lower_bound, 2), round(upper_bound, 2)

estimate_population_mean(169.5 , 2.31 , 36)
# Out:
# (169.5, 168.75, 170.25)

# %% [markdown]
# # question 3
# Hypothesis testing is used to assess the plausibility of a hypothesis by using sample data. The test provides evidence concerning the plausibility of the hypothesis, given the data. Statistical analysts test a hypothesis by measuring and examining a random sample of the population being analyzed.
#
# Hypothesis testing allows the researcher to determine whether the data from the sample is statistically significant. Hypothesis testing is one of the most important processes for measuring the validity and reliability of outcomes in any systematic investigation

# %% [markdown]
# # question 4
#
# Null Hypothesis (H0) = mean height of male students > mean height of female students
#
# Alternate Hypothesis(H1) = mean height of male students =< mean height of female students

# %% [markdown]
# # question 5

# %%
import numpy as np
from scipy.stats import ttest_ind

# Generate two samples
male_weight = np.array([68, 72, 76, 80, 84]) # sample of male college students
female_weight = np.array([52, 56, 60, 64, 68]) # sample of female college students

# Calculate sample statistics
male_mean = np.mean(male_weight)
female_mean = np.mean(female_weight)
male_std = np.std(male_weight, ddof=1)
female_std = np.std(female_weight, ddof=1)
male_n = len(male_weight)
female_n = len(female_weight)

# Conduct two-sample t-test
t, p = ttest_ind(male_weight, female_weight, equal_var=False)

# Print results
print("Male mean weight:", male_mean)
print("Female mean weight:", female_mean)
print("Male standard deviation:", male_std)
print("Female standard deviation:", female_std)
print("Male sample size:", male_n)
print("Female sample size:", female_n)
print("t-statistic:", t)
print("p-value:", p)

alpha = 0.05
if p < alpha:
    print("We reject the null hypothesis.")
else:
    print("We fail to reject the null hypothesis.")
# Out:
# Male mean weight: 76.0
# Female mean weight: 60.0
# Male standard deviation: 6.324555320336759
# Female standard deviation: 6.324555320336759
# Male sample size: 5
# Female sample size: 5
# t-statistic: 4.0
# p-value: 0.003949772803445322
# We reject the null hypothesis.

# %% [markdown]
# # question 6
#
# The null hypothesis is the one to be tested and the alternative is everything else. In our example: The null hypothesis would be: The mean data scientist salary is 113,000 dollars. While the alternative: The mean data scientist salary is not 113,000 dollars.
#
# Null Hypothesis: On the average, the dosage sold under this brand is 50 mg (population mean dosage = 50 mg). Alternative Hypothesis: On the average, the dosage sold under this brand is not 50 mg (population mean dosage ≠ 50 mg).

# %% [markdown]
# # question 7
#
# Step 1: State your null and alternate hypothesis.
#
# Step 2: Collect data.
#
# Step 3: Decision boundary.
#
# Step 4: Perform the statistical analysis based on the type of test selected ( Z-test , T-test or p value).
#
# Step 5: Decide whether to reject or fail to reject your null hypothesis.
#
# step 6: Present your findings.

# %% [markdown]
# # question 8
# The p value is a number, calculated from a statistical test, that describes how likely you are to have found a particular set of observations if the null hypothesis were true. P values are used in hypothesis testing to help decide whether to reject the null hypothesis.
#
# If the p value is less than significance value then the null hypothesis is rejected. Otherwise, it is accepted.

# %% [markdown]
# # question 9

# %%
import matplotlib.pyplot as plt
from scipy.stats import t
import numpy as np

# set the degrees of freedom
df = 10

# generate x values for the plot
x = np.linspace(t.ppf(0.001, df), t.ppf(0.999, df), 1000)

# generate the y values for the plot (the probability density function)
y = t.pdf(x, df)

# plot the t-distribution
plt.plot(x, y)

# set the plot title and axis labels
plt.title("Student's t-Distribution (df=10)")
plt.xlabel("x")
plt.ylabel("PDF")

# display the plot
plt.show()

# %% [markdown]
# # question 10

# %%
# question 10

import numpy as np
from scipy.stats import ttest_ind

# generate two random samples of equal size
sample1 = np.random.normal(loc=5, scale=2, size=100)
sample2 = np.random.normal(loc=5, scale=2, size=100)

# calculate the t-statistic and p-value using scipy's ttest_ind function
t_statistic, p_value = ttest_ind(sample1, sample2)

# print the results
print("T-Statistic: ", t_statistic)
print("P-Value: ", p_value)

# check for statistical significance at the alpha=0.05 level
if p_value < 0.05:
    print("Reject the null hypothesis - there is evidence of a significant difference in the population means.")
else:
    print("Fail to reject the null hypothesis - there is no evidence of a significant difference in the population means.")
# Out:
# T-Statistic:  -0.35600020931437815
# P-Value:  0.7222194282536163
# Fail to reject the null hypothesis - there is no evidence of a significant difference in the population means.

# %% [markdown]
# # question 11
#
# Student's t-distribution is a probability distribution that arises when estimating the mean of a normally distributed population in situations where the sample size is small, or when the population variance is unknown. It is named after William Gosset, who wrote under the pseudonym "Student".
#
# The t-distribution looks similar to a normal distribution, but with heavier tails. The shape of the t-distribution depends on the sample size, with larger sample sizes leading to distributions that are increasingly similar to the normal distribution.
#
# The t-distribution is commonly used in hypothesis testing and confidence interval estimation. It is used when the sample size is small and/or the population variance is unknown. Specifically, when the sample size is less than 30 or the population standard deviation is unknown, the t-distribution should be used instead of the standard normal distribution. The t-distribution is also used in linear regression analysis, where it is used to test hypotheses about the regression coefficients.

# %% [markdown]
# # question 12
# You can use a t-test to evaluate a sample of a larger population from previous z-tests. Applying the t-value formula, determine the sample size, the sample mean and the standard deviation of the sample.
#
# t = (X‾ - μ0) / (s / √n)

# %% [markdown]
# # question 13
#
# To estimate the population mean revenue with a 95% confidence interval, we can use the following formula:
#
# Confidence Interval = Sample Mean ± (Z Score) * (Standard Error)
#
# where the Z Score is determined by the desired level of confidence and the Standard Error is the Standard Deviation of the sample divided by the square root of the sample size.
#
# In this case, we are looking for a 95% confidence interval, which corresponds to a Z Score of 1.96 (from a standard normal distribution). We are given a sample mean of $500 and a standard deviation of $50 for a sample size of 50.
#
# Using these values, we can calculate the Standard Error as follows:
#
# Standard Error = Standard Deviation / sqrt(sample size)
# Standard Error = $50 / sqrt(50)
# Standard Error = $7.07
#
# Plugging these values into the formula, we get:
#
# Confidence Interval = $500 ± (1.96) * ($7.07)
# Confidence Interval = $500 ± $13.88
#
# Therefore, the 95% confidence interval for the population mean revenue is $486.12 to $513.88. We can be 95% confident that the true population mean revenue falls within this range.

# %% [markdown]
# # question 14

# %% [markdown]
# To test the hypothesis, we can use a one-sample t-test.
#
# The null hypothesis, H0: the drug has no effect on blood pressure, or the mean decrease in blood pressure is not 10 mmHg.
#
# The alternative hypothesis, Ha: the drug decreases blood pressure by 10 mmHg, or the mean decrease in blood pressure is 10 mmHg.
#
# We can calculate the t-value as follows:
#
# t = (sample mean - hypothesized mean) / (standard deviation / sqrt(sample size))
#
# t = (8 - 10) / (3 / sqrt(100))
#
# t = -20 / 3
#
# t = -6.67
#
# Using a t-distribution table with degrees of freedom (df) = n - 1 = 99 and a significance level of 0.05, we find the critical t-value to be ±1.984.
#
# Since our calculated t-value (-6.67) is less than the critical t-value (-1.984), we can reject the null hypothesis and conclude that the drug decreases blood pressure by 10 mmHg.
#
# Therefore, the evidence suggests that the new drug is effective in decreasing blood pressure by 10 mmHg.

# %% [markdown]
# # question 15
# To test the hypothesis, we can use a one-sample t-test.
#
# The null hypothesis, H0: the true mean weight of the products is 5 pounds.
#
# The alternative hypothesis, Ha: the true mean weight of the products is less than 5 pounds.
#
# We can calculate the t-value as follows:
#
# t = (sample mean - hypothesized mean) / (standard deviation / sqrt(sample size))
#
# t = (4.8 - 5) / (0.5 / sqrt(25))
#
# t = -1 / 0.1
#
# t = -10
#
# Using a t-distribution table with degrees of freedom (df) = n - 1 = 24 and a significance level of 0.01, we find the critical t-value to be -2.492.
#
# Since our calculated t-value (-10) is less than the critical t-value (-2.492), we can reject the null hypothesis and conclude that the true mean weight of the products is less than 5 pounds at a significance level of 0.01.
#
# Therefore, the evidence suggests that the company's production process may need to be adjusted to increase the weight of the products to meet the desired weight of 5 pounds.

# %% [markdown]
# # question 16
#
# To test the hypothesis, we can use a two-sample t-test assuming unequal variances.
#
# The null hypothesis, H0: the population means for the two groups are equal.
#
# The alternative hypothesis, Ha: the population means for the two groups are not equal.
#
# We can calculate the t-value as follows:
#
# t = (sample mean difference - hypothesized mean difference) / standard error
#
# standard error = sqrt((s1^2/n1) + (s2^2/n2))
#
# sample mean difference = x1 - x2
#
# hypothesized mean difference = 0
#
# x1 = 80, s1 = 10, n1 = 30
#
# x2 = 75, s2 = 8, n2 = 40
#
# sample mean difference = 80 - 75 = 5
#
# standard error = sqrt((10^2/30) + (8^2/40))
#
# standard error = 2.47
#
# t = (5 - 0) / 2.47
#
# t = 2.02
#
# Using a t-distribution table with degrees of freedom (df) calculated as follows:
#
# df = ((s1^2/n1 + s2^2/n2)^2) / ((s1^2/n1)^2/(n1-1) + (s2^2/n2)^2/(n2-1))
#
# df = ((10^2/30 + 8^2/40)^2) / ((10^2/30)^2/29 + (8^2/40)^2/39)
#
# df = 63.63
#
# With a significance level of 0.01, we find the critical t-value to be ±2.660.
#
# Since our calculated t-value (2.02) is less than the critical t-value (2.660), we fail to reject the null hypothesis and conclude that there is not enough evidence to suggest that the population means for the two groups are different at a significance level of 0.01.
#
# Therefore, the study materials provided to the two groups appear to have similar effects on their test scores.

# %% [markdown]
# # question 17
#
# To estimate the population mean with a 99% confidence interval, we can use the t-distribution and the following formula:
#
# Confidence interval = sample mean ± t-value * (standard error)
#
# where the t-value is obtained from the t-distribution table with n - 1 degrees of freedom and a 99% confidence level, and the standard error is calculated as:
#
# standard error = sample standard deviation / sqrt(sample size)
#
# In this case, n = 50, sample mean = 4, and sample standard deviation = 1.5.
#
# First, let's find the t-value from the t-distribution table with 49 degrees of freedom and a 99% confidence level. The critical value is ±2.677.
#
# Next, we can calculate the standard error:
#
# standard error = 1.5 / sqrt(50) = 0.212
#
# Substituting these values into the formula, we get:
#
# Confidence interval = 4 ± 2.677 * 0.212
#
# Confidence interval = [3.426, 4.574]
#
# Therefore, we can say with 99% confidence that the true average number of ads watched by viewers during the TV program is between 3.426 and 4.574.
